# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\BHUPESH\Desktop\Laptop_project\laptopPrice.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(21)

# %%
df.drop_duplicates( inplace= True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(10)
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8  Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 9    acer             AMD        Ryzen 5            10th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# ...

# %%
df.tail(20)
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 803    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 804    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 805    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 806    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 807      HP             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 808    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 809    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 810    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 811    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 812    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 813    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# ...

# %%
df.brand
# Out:
# 0        ASUS
# 1      Lenovo
# 2      Lenovo
# 3        ASUS
# 4        ASUS
#         ...
# 818      ASUS
# 819      ASUS
# 820      ASUS
# 821      ASUS
# 822    Lenovo
# Name: brand, Length: 802, dtype: object

# %%
df.ssd
# Out:
# 0         0 GB
# 1         0 GB
# 2         0 GB
# 3       512 GB
# 4         0 GB
#         ...
# 818    1024 GB
# 819    1024 GB
# 820    1024 GB
# 821    1024 GB
# 822     512 GB
# Name: ssd, Length: 802, dtype: object

# %%
df['brand'].value_counts()
# Out:
# brand
# ASUS      243
# DELL      149
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      23
# Avita       6
# Name: count, dtype: int64

# %%
df['processor_name'].value_counts()
# Out:
# processor_name
# Core i5         284
# Core i3         161
# Core i7         104
# Ryzen 5          82
# Ryzen 7          56
# Ryzen 9          26
# Ryzen 3          26
# Celeron Dual     23
# M1               19
# Pentium Quad     13
# Core i9           8
# Name: count, dtype: int64

# %%
df['ssd'].unique()
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
df['ssd'].nunique()
# Out:
# 7

# %%
df.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
df.rename(columns={'processor_gnrtn':'gen'},inplace=True)
df.rename(columns={'processor_name':'processor'},inplace=True)
df.rename(columns={'graphic_card_gb':'gpu'},inplace=True)
df.rename(columns={'ram_gb':'ram'},inplace=True)

# %%
df.drop(columns=['ram_type','weight'], inplace=True)

# %%
df
# Out:
#       brand processor_brand     processor            gen   ram      ssd  \
# 0      ASUS           Intel       Core i3           10th  4 GB     0 GB
# 1    Lenovo           Intel       Core i3           10th  4 GB     0 GB
# 2    Lenovo           Intel       Core i3           10th  4 GB     0 GB
# 3      ASUS           Intel       Core i5           10th  8 GB   512 GB
# 4      ASUS           Intel  Celeron Dual  Not Available  4 GB     0 GB
# ..      ...             ...           ...            ...   ...      ...
# 818    ASUS             AMD       Ryzen 9  Not Available  4 GB  1024 GB
# 819    ASUS             AMD       Ryzen 9  Not Available  4 GB  1024 GB
# 820    ASUS             AMD       Ryzen 9  Not Available  4 GB  1024 GB
# 821    ASUS             AMD       Ryzen 9  Not Available  4 GB  1024 GB
# 822  Lenovo             AMD       Ryzen 5           10th  8 GB   512 GB
#
#          hdd       os  os_bit   gpu     warranty Touchscreen msoffice   Price  \
# ...

# %%
char = df.select_dtypes(include='object')

# %%
char
# Out:
#       brand processor_brand     processor            gen   ram      ssd  \
# 0      ASUS           Intel       Core i3           10th  4 GB     0 GB
# 1    Lenovo           Intel       Core i3           10th  4 GB     0 GB
# 2    Lenovo           Intel       Core i3           10th  4 GB     0 GB
# 3      ASUS           Intel       Core i5           10th  8 GB   512 GB
# 4      ASUS           Intel  Celeron Dual  Not Available  4 GB     0 GB
# ..      ...             ...           ...            ...   ...      ...
# 818    ASUS             AMD       Ryzen 9  Not Available  4 GB  1024 GB
# 819    ASUS             AMD       Ryzen 9  Not Available  4 GB  1024 GB
# 820    ASUS             AMD       Ryzen 9  Not Available  4 GB  1024 GB
# 821    ASUS             AMD       Ryzen 9  Not Available  4 GB  1024 GB
# 822  Lenovo             AMD       Ryzen 5           10th  8 GB   512 GB
#
#          hdd       os  os_bit   gpu     warranty Touchscreen msoffice   rating
# ...

# %%
num = df.select_dtypes(exclude='object')

# %%
num
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [802 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
char['brand']=le.fit_transform(char['brand'])
char['processor_brand']=le.fit_transform(char['processor_brand'])
char['processor']=le.fit_transform(char['processor'])
char['gen']=le.fit_transform(char['gen'])
char['os']=le.fit_transform(char['os'])
char['os_bit']=le.fit_transform(char['os_bit'])
char['gpu']=le.fit_transform(char['gpu'])
char['warranty']=le.fit_transform(char['warranty'])
char['Touchscreen']=le.fit_transform(char['Touchscreen'])
char['msoffice']=le.fit_transform(char['msoffice'])

# %%
char['ram'] = char['ram'].astype(str).str.extract(r'(\d+)').astype('int')

char['ssd'] = char['ssd'].astype(str).str.extract(r'(\d+)').astype('int')

char['hdd'] = char['hdd'].astype(str).str.replace('TB', '000')
char['hdd'] = char['hdd'].str.extract(r'(\d+)').astype('int')

char['rating'] = pd.to_numeric(char['rating'].str.extract(r'(\d+)')[0], errors='coerce')

# %%
char
# Out:
#      brand  processor_brand  processor  gen  ram   ssd   hdd  os  os_bit  gpu  \
# 0        1                1          1    0    4     0  1024   2       1    0
# 1        5                1          1    0    4     0  1024   2       1    0
# 2        5                1          1    0    4     0  1024   2       1    0
# 3        1                1          2    0    8   512     0   2       0    1
# 4        1                1          0    7    4     0   512   2       1    0
# ..     ...              ...        ...  ...  ...   ...   ...  ..     ...  ...
# 818      1                0         10    7    4  1024     0   2       1    0
# 819      1                0         10    7    4  1024     0   2       1    0
# 820      1                0         10    7    4  1024     0   2       1    2
# 821      1                0         10    7    4  1024     0   2       1    2
# 822      5                0          8    0    8   512     0   0       1    0
#
# ...

# %%
clean_data = pd.concat([char,num], axis=1)

# %%
clean_data
# Out:
#      brand  processor_brand  processor  gen  ram   ssd   hdd  os  os_bit  gpu  \
# 0        1                1          1    0    4     0  1024   2       1    0
# 1        5                1          1    0    4     0  1024   2       1    0
# 2        5                1          1    0    4     0  1024   2       1    0
# 3        1                1          2    0    8   512     0   2       0    1
# 4        1                1          0    7    4     0   512   2       1    0
# ..     ...              ...        ...  ...  ...   ...   ...  ..     ...  ...
# 818      1                0         10    7    4  1024     0   2       1    0
# 819      1                0         10    7    4  1024     0   2       1    0
# 820      1                0         10    7    4  1024     0   2       1    2
# 821      1                0         10    7    4  1024     0   2       1    2
# 822      5                0          8    0    8   512     0   0       1    0
#
# ...

# %%
clean_data.to_csv("laptopPrice_cleaned.csv", index=False)
